# %%
import pandas as pd

# %%
df = pd.read_csv('/media/hoantranviet/data/ImageProcessing/Recursive-CNNs/dataset/selfCollectedData_CornDetec/gt.csv')

# %%
df
# Out:
#        Unnamed: 0  IMG_20170315_132900.jpg000.jpg   |(0.9266666666666666  \
# 0               0  IMG_20170315_132900.jpg001.jpg  |(0.15333333333333332
# 1               1  IMG_20170315_132900.jpg002.jpg   |(0.9266666666666666
# 2               2  IMG_20170315_132900.jpg003.jpg                 |(0.55
# 3               3  IMG_20170315_132900.jpg010.jpg   |(0.7433333333333333
# 4               4  IMG_20170315_132900.jpg011.jpg   |(0.8133333333333334
# 5               5  IMG_20170315_132900.jpg012.jpg   |(0.9766666666666667
# 6               6  IMG_20170315_132900.jpg013.jpg  |(0.48333333333333334
# 7               7  IMG_20170315_132900.jpg020.jpg   |(0.3233333333333333
# 8               8  IMG_20170315_132900.jpg021.jpg                 |(0.11
# 9               9  IMG_20170315_132900.jpg022.jpg   |(0.9566666666666667
# 10             10  IMG_20170315_132900.jpg023.jpg  |(0.29333333333333333
# 11             11  IMG_20170315_132900.jpg030.jpg                 |(0.86
# ...

# %%
import shutil
from tqdm import tqdm
import os

# %%
a = range(28413,20000, -1)

# %%
names = df['IMG_20170315_132900.jpg000.jpg']

# %%
folder_path = 'dataset/selfCollectedData_CornDetec'

# %%
for i in tqdm(a):
    df.drop(i)
#     shutil.copy()
    os.remove(os.path.join(folder_path, names[i]))
# Out:
# 100%|██████████| 8413/8413 [00:25<00:00, 324.50it/s]

# %%
df = df.drop(28414)

# %%
df.to_csv('gt.csv')

# %%
import numpy as np

# %%
a = np.array([1,1,12])

# %%
a
# Out:
# array([ 1,  1, 12])
